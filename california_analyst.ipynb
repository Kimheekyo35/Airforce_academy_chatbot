# %% [markdown]
# <a href="https://colab.research.google.com/github/Kimheekyo35/Airforce_academy_chatbot/blob/main/california_analyst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install kagglehub

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("uciml/adult-census-income")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'adult-census-income' dataset.
# Path to dataset files: /kaggle/input/adult-census-income

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../content/sample_data/california_housing_train.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
# 둘러보기
df.describe()
# Out:
#           longitude      latitude  ...  median_income  median_house_value
# count  17000.000000  17000.000000  ...   17000.000000        17000.000000
# mean    -119.562108     35.625225  ...       3.883578       207300.912353
# std        2.005166      2.137340  ...       1.908157       115983.764387
# min     -124.350000     32.540000  ...       0.499900        14999.000000
# 25%     -121.790000     33.930000  ...       2.566375       119400.000000
# 50%     -118.490000     34.250000  ...       3.544600       180400.000000
# 75%     -118.000000     37.720000  ...       4.767000       265000.000000
# max     -114.310000     41.950000  ...      15.000100       500001.000000
#
# [8 rows x 9 columns]

# %%
# null 값 확인
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
# row 개수, col 개수 알 수 있음
df.shape
# Out:
# (17000, 9)

# %%
# dataframe의 columns 아는 방법
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
# 해당 열의 data type 아는 방법
print(df['longitude'].dtype)
# Out:
# float64

# %%
def check_missing_col(dataframe):
  missing_col = []
  for col in dataframe.columns:
    missing_values = sum(dataframe[col].isna())
    is_missing = True if missing_values >= 1 else False
    # 만약 결측값이 있다면,
    if is_missing:
      print(f"결측치가 있는 컬럼은 {col} 입니다.")
      print(f'해당 컬럼에 총 {missing_values} 개의 결측치가 존재합니다.')
      missing_col.append(dataframe[col].dtype)
  if missing_col == []:
    print("결측치가 존재하지 않습니다.")
  return
  missing_col

print(check_missing_col(df))
# Out:
# 결측치가 존재하지 않습니다.
# []

# %% [markdown]
# ### unique()
#
# - 특정 열 또는 시리즈에서 중복된 값 모두 제거하고, 고유한 값들만 뽑아서 보여주는 기능

# %%
print(df['longitude'].unique())
# Out:
# [-114.31 -114.47 -114.56 -114.57 -114.58 -114.59 -114.6  -114.61 -114.63
#  -114.65 -114.66 -114.67 -114.68 -114.73 -114.94 -114.98 -115.22 -115.32
#  -115.37 -115.38 -115.39 -115.4  -115.41 -115.46 -115.48 -115.49 -115.5
#  -115.51 -115.52 -115.53 -115.54 -115.55 -115.56 -115.57 -115.58 -115.59
#  -115.6  -115.62 -115.64 -115.69 -115.72 -115.73 -115.8  -115.84 -115.85
#  -115.88 -115.9  -115.91 -115.93 -115.94 -115.95 -115.96 -115.98 -115.99
#  -116.   -116.01 -116.02 -116.05 -116.06 -116.08 -116.09 -116.11 -116.12
#  -116.14 -116.15 -116.16 -116.17 -116.18 -116.19 -116.2  -116.21 -116.22
#  -116.23 -116.24 -116.25 -116.26 -116.27 -116.29 -116.3  -116.31 -116.32
#  -116.33 -116.34 -116.35 -116.36 -116.37 -116.38 -116.39 -116.4  -116.41
#  -116.42 -116.43 -116.44 -116.45 -116.46 -116.47 -116.48 -116.49 -116.5
#  -116.51 -116.52 -116.53 -116.54 -116.55 -116.56 -116.57 -116.58 -116.6
#  -116.61 -116.62 -116.66 -116.67 -116.68 -116.71 -116.72 -116.74 -116.75
# ...

# %%
df[['longitude','total_rooms']]
# Out:
#        longitude  total_rooms
# 0        -114.31       5612.0
# 1        -114.47       7650.0
# 2        -114.56        720.0
# 3        -114.57       1501.0
# 4        -114.57       1454.0
# ...          ...          ...
# 16995    -124.26       2217.0
# 16996    -124.27       2349.0
# 16997    -124.30       2677.0
# 16998    -124.30       2672.0
# 16999    -124.35       1820.0
#
# [17000 rows x 2 columns]

# %%
df.loc[[0,1],['longitude','total_rooms']]
# Out:
#    longitude  total_rooms
# 0    -114.31       5612.0
# 1    -114.47       7650.0

# %%
df.iloc[[0,1]]
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -114.31     34.19  ...         1.4936             66900.0
# 1    -114.47     34.40  ...         1.8200             80100.0
#
# [2 rows x 9 columns]

# %%
#0이랑 3만 뽑음
df.iloc[[0,3]]
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -114.31     34.19  ...         1.4936             66900.0
# 3    -114.57     33.64  ...         3.1917             73400.0
#
# [2 rows x 9 columns]

# %%
# 0부터 2까지의 행을 모두 뽑음
df.iloc[0:3]
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -114.31     34.19  ...         1.4936             66900.0
# 1    -114.47     34.40  ...         1.8200             80100.0
# 2    -114.56     33.69  ...         1.6509             85700.0
#
# [3 rows x 9 columns]

# %% [markdown]
# ### iloc[x,y] - integer location
#
# - 특정한 행과 열 찾고싶으면 이렇게 하면 됨
#
# ### loc[x,y] - location (이름 Label기반)

# %%
# 0번째 행, 3번째 열 찾고싶을 때

df.iloc[0,3]
# Out:
# np.float64(5612.0)

# %%
df.loc[0,'total_rooms']
# Out:
# np.float64(5612.0)
